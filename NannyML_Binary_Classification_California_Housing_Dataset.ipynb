# %% [markdown]
# <a href="https://colab.research.google.com/github/arailymmmm/Machine-Learning-Tutorial-Python/blob/main/NannyML_Binary_Classification_California_Housing_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nannyml
# Out:
# Requirement already satisfied: nannyml in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Requirement already satisfied: APScheduler<4.0,>=3.9 in /usr/local/lib/python3.12/dist-packages (from nannyml) (3.11.0)
# Requirement already satisfied: FLAML<3.0.0,>=2.3.3 in /usr/local/lib/python3.12/dist-packages (from FLAML[automl]<3.0.0,>=2.3.3->nannyml) (2.3.6)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from nannyml) (3.1.6)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from nannyml) (6.0.3)
# Requirement already satisfied: category-encoders<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from nannyml) (2.8.1)
# Requirement already satisfied: click<9.0,>=8.1 in /usr/local/lib/python3.12/dist-packages (from nannyml) (8.3.0)
# Requirement already satisfied: gcsfs>=2022.5 in /usr/local/lib/python3.12/dist-packages (from nannyml) (2025.3.0)
# Requirement already satisfied: joblib<2.0,>=1.1 in /usr/local/lib/python3.12/dist-packages (from nannyml) (1.5.2)
# Requirement already satisfied: kaleido<0.3,>=0.2 in /usr/local/lib/python3.12/dist-packages (from nannyml) (0.2.1)
# Requirement already satisfied: lightgbm<4.6,>=3.3 in /usr/local/lib/python3.12/dist-packages (from nannyml) (4.5.0)
# Requirement already satisfied: matplotlib<4.0,>=3.7 in /usr/local/lib/python3.12/dist-packages (from nannyml) (3.10.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from nannyml) (1.26.4)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.12/dist-packages (from nannyml) (2.2.2)
# Requirement already satisfied: plotly<6.0,>=5.6 in /usr/local/lib/python3.12/dist-packages (from nannyml) (5.24.1)
# Requirement already satisfied: pyarrow>=13.0 in /usr/local/lib/python3.12/dist-packages (from nannyml) (18.1.0)
# Requirement already satisfied: pydantic>=2.7 in /usr/local/lib/python3.12/dist-packages (from nannyml) (2.11.9)
# Requirement already satisfied: pyfiglet<0.9,>=0.8.post1 in /usr/local/lib/python3.12/dist-packages (from nannyml) (0.8.post1)
# Requirement already satisfied: python-dateutil<3.0,>=2.8 in /usr/local/lib/python3.12/dist-packages (from nannyml) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from nannyml) (1.1.1)
# Requirement already satisfied: rich>=12.5 in /usr/local/lib/python3.12/dist-packages (from nannyml) (13.9.4)
# Requirement already satisfied: s3fs>=2022.8 in /usr/local/lib/python3.12/dist-packages (from nannyml) (2025.3.0)
# Requirement already satisfied: scikit-learn>=1.3 in /usr/local/lib/python3.12/dist-packages (from nannyml) (1.6.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.12/dist-packages (from nannyml) (1.16.2)
# Requirement already satisfied: seaborn<0.14,>=0.13 in /usr/local/lib/python3.12/dist-packages (from nannyml) (0.13.2)
# Requirement already satisfied: segment-analytics-python<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from nannyml) (2.3.4)
# Requirement already satisfied: tzlocal>=3.0 in /usr/local/lib/python3.12/dist-packages (from APScheduler<4.0,>=3.9->nannyml) (5.3.1)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from category-encoders<3.0,>=2.3->nannyml) (1.0.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from category-encoders<3.0,>=2.3->nannyml) (0.14.5)
# Requirement already satisfied: xgboost<3.0.0,>=0.90 in /usr/local/lib/python3.12/dist-packages (from FLAML[automl]<3.0.0,>=2.3.3->nannyml) (2.1.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2022.5->nannyml) (3.12.15)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2022.5->nannyml) (4.4.2)
# Requirement already satisfied: fsspec==2025.3.0 in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2022.5->nannyml) (2025.3.0)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2022.5->nannyml) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2022.5->nannyml) (1.2.2)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2022.5->nannyml) (2.19.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2022.5->nannyml) (2.32.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=3.1->nannyml) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nannyml) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nannyml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nannyml) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nannyml) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nannyml) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nannyml) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nannyml) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->nannyml) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->nannyml) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly<6.0,>=5.6->nannyml) (8.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7->nannyml) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7->nannyml) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7->nannyml) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7->nannyml) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0,>=2.8->nannyml) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.5->nannyml) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.5->nannyml) (2.19.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /usr/local/lib/python3.12/dist-packages (from s3fs>=2022.8->nannyml) (2.24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->nannyml) (3.6.0)
# Requirement already satisfied: backoff~=2.1 in /usr/local/lib/python3.12/dist-packages (from segment-analytics-python<3.0,>=2.3->nannyml) (2.2.1)
# Requirement already satisfied: PyJWT~=2.10.1 in /usr/local/lib/python3.12/dist-packages (from segment-analytics-python<3.0,>=2.3->nannyml) (2.10.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.8->nannyml) (0.12.0)
# Requirement already satisfied: botocore<1.40.19,>=1.40.15 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.8->nannyml) (1.40.18)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.8->nannyml) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.8->nannyml) (6.6.4)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.8->nannyml) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.5->nannyml) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.5->nannyml) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.5->nannyml) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.5->nannyml) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.5->nannyml) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.5->nannyml) (1.20.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2022.5->nannyml) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2022.5->nannyml) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2022.5->nannyml) (4.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.5->nannyml) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs>=2022.5->nannyml) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs>=2022.5->nannyml) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs>=2022.5->nannyml) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs>=2022.5->nannyml) (2025.8.3)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost<3.0.0,>=0.90->FLAML[automl]<3.0.0,>=2.3.3->nannyml) (2.27.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib->gcsfs>=2022.5->nannyml) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs>=2022.5->nannyml) (2.25.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs>=2022.5->nannyml) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs>=2022.5->nannyml) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs>=2022.5->nannyml) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs>=2022.5->nannyml) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs>=2022.5->nannyml) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs>=2022.5->nannyml) (1.26.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=2022.5->nannyml) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2022.5->nannyml) (3.3.1)

# %%
# !pip install "numpy<2.0" -U
# Out:
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.12/dist-packages (1.26.4)

# %%
import pandas as pd
import nannyml as nml
reference_df, analysis_df, analysis_targets_df = nml.datasets.load_modified_california_housing_dataset()
reference_df.head(3)
# Out:
#    id  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0   0  9.8413      32.0  7.170040   1.014845      4353.0  2.937247     34.22
# 1   1  8.3695      37.0  7.458746   1.062706       941.0  3.105611     34.22
# 2   2  8.7200      44.0  6.163180   1.046025       668.0  2.794979     34.20
#
#    Longitude            timestamp  clf_target  y_pred_proba  y_pred
# 0    -118.19  2020-10-01 00:00:00           1          0.99       1
# 1    -118.21  2020-10-01 01:00:00           1          1.00       1
# 2    -118.18  2020-10-01 02:00:00           1          1.00       1

# %%
analysis_df.head(3)
# Out:
#      id  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0  5832  3.4583      24.0  5.207101   1.106509       507.0  3.000000
# 1  5833  2.0250      33.0  3.432099   1.123457       375.0  4.629630
# 2  5834  3.7750      25.0  5.600000   1.111230      2725.0  2.914439
#
#    Latitude  Longitude            timestamp  y_pred_proba  y_pred
# 0     33.81    -116.25  2021-06-01 00:00:00          0.18       0
# 1     33.75    -116.25  2021-06-01 01:00:00          0.09       0
# 2     33.72    -116.24  2021-06-01 02:00:00          0.27       0

# %%
analysis_targets_df.head(3)
# Out:
#      id  clf_target
# 0  5832           0
# 1  5833           0
# 2  5834           0

# %%
# fit performance estimator and estimate for combined reference and analysis
cbpe = nml.CBPE(
    y_pred='y_pred',
    y_pred_proba='y_pred_proba',
    y_true='clf_target',
    timestamp_column_name='timestamp',
    problem_type='classification_binary',
    chunk_period='M',
    metrics=['roc_auc'])
cbpe.fit(reference_data=reference_df)
est_perf = cbpe.estimate(analysis_df)
# Out:
# WARNING:nannyml.performance_estimation.confidence_based.metrics:roc_auc upper threshold value 1.0495925664056327 overridden by upper threshold value limit 1

# %%
est_perf.data = est_perf.data[:-1].copy()
est_perf.data.tail(2)
# Out:
#       chunk                                               \
#         key chunk_index start_index end_index start_date
# 17  2022-03           9        6552      7295 2022-03-01
# 18  2022-04          10        7296      8015 2022-04-01
#
#                                              roc_auc                          \
#                         end_date    period     value sampling_error realized
# 17 2022-03-31 23:59:59.999999999  analysis  0.829077       0.007781      NaN
# 18 2022-04-30 23:59:59.999999999  analysis  0.910661       0.007910      NaN
#
#                                                                         \
#    upper_confidence_boundary lower_confidence_boundary upper_threshold
# 17                   0.85242                  0.805734               1
# 18                   0.93439                  0.886932               1
#
#
#    lower_threshold  alert
# 17        0.708336  False
# 18        0.708336  False

# %%
fig = est_perf.filter(metrics=['roc_auc'], period='analysis').plot()
fig.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/plotly/io/_json.py:560: UserWarning:
#
# Discarding nonzero nanoseconds in conversion.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0319da9b-f79c-474b-9f5e-cbec9afc53cf" class="plotly-graph-div" style="height:500.0px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0319da9b-f79c-474b-9f5e-cbec9afc53cf")) {                    Plotly.newPlot(                        "0319da9b-f79c-474b-9f5e-cbec9afc53cf",                        [{"hoverinfo":"skip","legendgroup":"metric_analysis","line":{"color":"#3b0280","dash":"dash","shape":"hv","width":2},"mode":"lines","name":"Metric","showlegend":true,"x":["2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-04-30T23:59:59.999999"],"y":[0.8593184954494558,0.7509762665508896,0.7092835532562947,0.664344087569458,0.8242907162753387,0.8702539407159626,0.8982734566015735,0.8515734540988419,0.9110542503983892,0.8290768942764435,0.9106610766431227,0.9106610766431227],"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":[["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eAnalysis\u003c\u002fb\u003e","","2021-06","From \u003cb\u003eJun-01-2021\u003c\u002fb\u003e to \u003cb\u003eJun-30-2021\u003c\u002fb\u003e",0.8593,0.0237],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eAnalysis\u003c\u002fb\u003e","","2021-07","From \u003cb\u003eJul-01-2021\u003c\u002fb\u003e to \u003cb\u003eJul-31-2021\u003c\u002fb\u003e",0.751,0.0233],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eAnalysis\u003c\u002fb\u003e","","2021-08","From \u003cb\u003eAug-01-2021\u003c\u002fb\u003e to \u003cb\u003eAug-31-2021\u003c\u002fb\u003e",0.7093,0.0233],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eAnalysis\u003c\u002fb\u003e","\u003cspan style=\"color:#AD0000\"\u003e⚠ \u003cb\u003eDrift detected\u003c\u002fb\u003e\u003c\u002fspan\u003e","2021-09","From \u003cb\u003eSep-01-2021\u003c\u002fb\u003e to \u003cb\u003eSep-30-2021\u003c\u002fb\u003e",0.6643,0.0237],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eAnalysis\u003c\u002fb\u003e","","2021-10","From \u003cb\u003eOct-01-2021\u003c\u002fb\u003e to \u003cb\u003eOct-31-2021\u003c\u002fb\u003e",0.8243,0.0233],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eAnalysis\u003c\u002fb\u003e","","2021-11","From \u003cb\u003eNov-01-2021\u003c\u002fb\u003e to \u003cb\u003eNov-30-2021\u003c\u002fb\u003e",0.8703,0.0237],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eAnalysis\u003c\u002fb\u003e","","2021-12","From \u003cb\u003eDec-01-2021\u003c\u002fb\u003e to \u003cb\u003eDec-31-2021\u003c\u002fb\u003e",0.8983,0.0233],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eAnalysis\u003c\u002fb\u003e","","2022-01","From \u003cb\u003eJan-01-2022\u003c\u002fb\u003e to \u003cb\u003eJan-31-2022\u003c\u002fb\u003e",0.8516,0.0233],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eAnalysis\u003c\u002fb\u003e","","2022-02","From \u003cb\u003eFeb-01-2022\u003c\u002fb\u003e to \u003cb\u003eFeb-28-2022\u003c\u002fb\u003e",0.9111,0.0246],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;li ...

# %%
fig = est_perf.filter(metrics=['roc_auc']).plot()
fig.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/plotly/io/_json.py:560: UserWarning:
#
# Discarding nonzero nanoseconds in conversion.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bdcfa700-a965-41c1-8289-42423ecb8d4a" class="plotly-graph-div" style="height:500.0px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bdcfa700-a965-41c1-8289-42423ecb8d4a")) {                    Plotly.newPlot(                        "bdcfa700-a965-41c1-8289-42423ecb8d4a",                        [{"hoverinfo":"skip","legendgroup":"metric_reference","line":{"color":"#3b0280","dash":"dash","shape":"hv","width":2},"mode":"lines","name":"Metric","showlegend":true,"x":["2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-05-31T23:59:59.999999"],"y":[0.9272511244902255,0.9076245277015762,0.9096517460426643,0.9466370323586943,0.881041185586536,0.8442319175419,0.8740140073775035,0.7905435058375979,0.7905435058375979],"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":[["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eReference\u003c\u002fb\u003e","","2020-10","From \u003cb\u003eOct-01-2020\u003c\u002fb\u003e to \u003cb\u003eOct-31-2020\u003c\u002fb\u003e",0.9273,0.0233],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eReference\u003c\u002fb\u003e","","2020-11","From \u003cb\u003eNov-01-2020\u003c\u002fb\u003e to \u003cb\u003eNov-30-2020\u003c\u002fb\u003e",0.9076,0.0237],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eReference\u003c\u002fb\u003e","","2020-12","From \u003cb\u003eDec-01-2020\u003c\u002fb\u003e to \u003cb\u003eDec-31-2020\u003c\u002fb\u003e",0.9097,0.0233],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eReference\u003c\u002fb\u003e","","2021-01","From \u003cb\u003eJan-01-2021\u003c\u002fb\u003e to \u003cb\u003eJan-31-2021\u003c\u002fb\u003e",0.9466,0.0233],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eReference\u003c\u002fb\u003e","","2021-02","From \u003cb\u003eFeb-01-2021\u003c\u002fb\u003e to \u003cb\u003eFeb-28-2021\u003c\u002fb\u003e",0.881,0.0246],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eReference\u003c\u002fb\u003e","","2021-03","From \u003cb\u003eMar-01-2021\u003c\u002fb\u003e to \u003cb\u003eMar-31-2021\u003c\u002fb\u003e",0.8442,0.0233],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eReference\u003c\u002fb\u003e","","2021-04","From \u003cb\u003eApr-01-2021\u003c\u002fb\u003e to \u003cb\u003eApr-30-2021\u003c\u002fb\u003e",0.874,0.0237],["Estimated \u003cb\u003eROC AUC\u003c\u002fb\u003e","\u003cb style=\"color:Colors.INDIGO_PERSIAN;line-height:60px\"\u003eReference\u003c\u002fb\u003e","","2021-05","From \u003cb\u003eMay-01-2021\u003c\u002fb\u003e to \u003cb\u003eMay-31-2021\u003c\u002fb\u003e",0.7905,0.0233]],"hovertemplate":"%{customdata[1]} &nbsp; &nbsp; %{customdata[2]} \u003cbr \u002f\u003eChunk: \u003cb\u003e%{customdata[3]}\u003c\u002fb\u003e &nbsp; &nbsp; %{customdata[4]} \u003cbr \u002f\u003e%{customdata[0]}: \u003cb\u003e%{customdata[5]}\u003c\u002fb\u003e\u003cbr \u002f\u003eConfidence band: +\u002f- \u003cb\u003e%{customdata[6]}\u003c\u002fb\u003e\u003cbr \u002f\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"metric_reference","line":{"dash":"dash"},"marker":{"color":"#3b0280","size":5,"symbol":"circle"},"mode":"markers","name":"Metric","showlegend":false,"x":["2020-10-16T12:00 ...

# %%
est_perf_data = est_perf.to_df()

# %%
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
# add ground truth to analysis
analysis_full = pd.merge(analysis_df, analysis_targets_df, left_index=True, right_index=True)
df_all = pd.concat([reference_df, analysis_full]).reset_index(drop=True)
df_all['timestamp'] = pd.to_datetime(df_all['timestamp'])
# calculate actual ROC AUC
target_col = cbpe.y_true
pred_score_col = 'y_pred_proba'
actual_performance = []
for idx in est_perf_data.index:
    start_date, end_date = est_perf_data.loc[idx, ('chunk', 'start_date')], est_perf_data.loc[idx, ('chunk', 'end_date')]
    sub = df_all[df_all['timestamp'].between(start_date, end_date)]
    actual_perf = roc_auc_score(sub[target_col], sub[pred_score_col])
    est_perf_data.loc[idx, ('roc_auc', 'realized')] = actual_perf
# plot
first_analysis = est_perf_data[('chunk', 'key')].values[8]
plt.figure(figsize=(10,5))
plt.plot(est_perf_data[('chunk', 'key')], est_perf_data[('roc_auc', 'value')], label='estimated AUC')
plt.plot(est_perf_data[('chunk', 'key')], est_perf_data[('roc_auc', 'realized')], label='actual ROC AUC')
plt.xticks(rotation=90)
plt.axvline(x=first_analysis, label='First analysis chunk', linestyle=':', color='grey')
plt.ylabel('ROC AUC')
plt.legend()
plt.show()

# %%
feature_column_names = [
    col for col in reference_df
    if col not in ['y_pred', 'y_pred_proba', 'clf_target', 'timestamp']]

univariate_calculator = nml.UnivariateDriftCalculator(column_names=feature_column_names,
                                                      timestamp_column_name='timestamp',
                                                      chunk_period='M',
                                                      continuous_methods=['kolmogorov_smirnov'],
                                                      categorical_methods=['chi2']).fit(reference_data=reference_df)
univariate_results = univariate_calculator.calculate(analysis_df)
nml.AlertCountRanker().rank(univariate_results)
# Out:
# WARNING:nannyml.drift.univariate.methods:Kolmogorov-Smirnov statistic upper threshold value 1.1033567331235616 overridden by upper threshold value limit 1
#    number_of_alerts column_name  rank
# 0                 3   Longitude     1
# 1                 1    Latitude     2
# 2                 0          id     3
# 3                 0  Population     4
# 4                 0      MedInc     5
# 5                 0    HouseAge     6
# 6                 0    AveRooms     7
# 7                 0    AveOccup     8
# 8                 0   AveBedrms     9

# %%
# get columns with d statistics only
# # # print(result.data.loc[:, (non_chunk, slice(None), 'alert')])
univariate_results.to_df().loc[:, (slice(None), 'kolmogorov_smirnov', 'value')].mean().sort_values(ascending=False)
# Out:
# id          kolmogorov_smirnov  value    0.874280
# Longitude   kolmogorov_smirnov  value    0.712709
# Latitude    kolmogorov_smirnov  value    0.672904
# HouseAge    kolmogorov_smirnov  value    0.201638
# MedInc      kolmogorov_smirnov  value    0.154952
# AveOccup    kolmogorov_smirnov  value    0.143890
# AveRooms    kolmogorov_smirnov  value    0.129277
# AveBedrms   kolmogorov_smirnov  value    0.089140
# Population  kolmogorov_smirnov  value    0.073562
# dtype: float64

# %%
fig = univariate_results.filter(
    column_names=['Longitude', 'Latitude'],
    period='analysis',
    methods=['kolmogorov_smirnov']
).plot(kind='distribution', number_of_columns=1)
fig.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/plotly/io/_json.py:560: UserWarning:
#
# Discarding nonzero nanoseconds in conversion.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="315b5cf6-700e-4a4b-8412-7e1c889762f2" class="plotly-graph-div" style="height:1000.0px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("315b5cf6-700e-4a4b-8412-7e1c889762f2")) {                    Plotly.newPlot(                        "315b5cf6-700e-4a4b-8412-7e1c889762f2",                        [{"hoverinfo":"skip","line":{"color":"#3b0280","width":1},"mode":"lines","name":"Analysis","showlegend":false,"x":["2021-05-31T23:50:08.988945760","2021-05-31T22:48:11.498247086","2021-05-31T17:37:44.584847459","2021-05-31T08:41:06.111370152","2021-05-31T03:32:36.395071679","2021-05-31T06:56:56.341121817","2021-05-31T07:20:42.038668233","2021-05-30T16:57:54.292106943","2021-05-30T01:24:22.037364454","2021-05-29T18:37:42.040359736","2021-05-29T12:13:15.061775655","2021-05-29T10:41:54.847187230","2021-05-29T23:07:42.353599381","2021-05-30T23:31:29.733116469","2021-05-31T14:43:28.213093675","2021-05-31T15:50:31.438075917","2021-05-31T15:45:32.166233747","2021-05-31T16:00:14.864808022","2021-05-31T16:52:26.428957388","2021-05-31T18:21:47.400502151","2021-05-31T19:20:51.133882439","2021-05-31T19:47:20.011156548","2021-05-31T21:38:26.732996827","2021-05-31T23:29:39.942125458","2021-05-31T23:57:45.493500473","2021-05-31T23:59:56.620410006","2021-05-31T23:59:59.971185232","2021-05-31T23:59:59.999916668","2021-05-31T23:59:59.999999919","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.000000000","2021-06-01T00:00:00.00 ...

# %%
analysis_res = est_perf.data
plt.figure(figsize=(8,6))
for idx in analysis_res.index[:10]:
    start_date, end_date = analysis_res.loc[idx, ('chunk', 'start_date')], analysis_res.loc[idx, ('chunk', 'end_date')]
    sub = df_all[df_all['timestamp'].between(start_date, end_date)]
    plt.scatter(sub['Latitude'], sub['Longitude'], s=5, label="Chunk {}".format(str(idx)))

plt.legend()
plt.xlabel('Latitude')
plt.ylabel('Longitude')
# Out:
# Text(0, 0.5, 'Longitude')
